# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, precision_score, recall_score
import warnings

# Suppress Warnings
warnings.filterwarnings('ignore')

# Seed Initialization
np.random.seed(42)

# Load Data
file_path = '/content/drive/My Drive/Data_ADNIMerge_procssedNeuroImaging.csv'
data = pd.read_csv(file_path)

# Visualize Class Distribution Before SMOTE
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='AD_LABEL', data=data)
plt.title('Class Distribution Before SMOTE')
plt.xlabel('Class')
plt.ylabel('Count')

# Data Preprocessing
data = data.drop(["RID"], axis=1)

# Separate Features and Target
X = data.drop("AD_LABEL", axis=1)
y = data["AD_LABEL"] - 1

# Apply SMOTE to both features and target
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Visualize Class Distribution After SMOTE
plt.subplot(1, 2, 2)
sns.countplot(x=y_resampled)
plt.title('Class Distribution After SMOTE')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data.shape
# Out:
# (559, 223)

# %%
class ConfidenceSoftmax(tf.keras.layers.Layer):
    def __init__(self, temperature=1.5, **kwargs):
        super(ConfidenceSoftmax, self).__init__(**kwargs)
        self.temperature = temperature

    def call(self, inputs):
        scaled_inputs = inputs / self.temperature
        softmax = tf.nn.softmax(scaled_inputs)
        confidence = tf.reduce_max(softmax, axis=-1, keepdims=True)
        return tf.concat([softmax, confidence], axis=-1)

# Define Neural Network Model with Confidence Softmax Layer
def create_model_with_confidence(temperature=1.5):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(223, activation='relu', input_shape=(X_resampled.shape[1],)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(3),
        ConfidenceSoftmax(temperature)  # Confidence softmax as a layer
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Initialize Cross-Validation (Leave-One-Out)
loo = LeaveOneOut()

# Perform Cross-Validation
predictions = []
true_labels = []
confidences = []
accuracies = []

for train_index, test_index in loo.split(X_resampled):
    X_train_loo, X_test_loo = X_resampled.iloc[train_index], X_resampled.iloc[test_index]
    y_train_loo, y_test_loo = y_resampled[train_index], y_resampled[test_index]

    model = create_model_with_confidence(temperature=1.0)  # Adjust temperature here
    model.fit(X_train_loo, y_train_loo, epochs=10, verbose=0)

    prediction_with_confidence = model.predict(X_test_loo)
    predicted_class = np.argmax(prediction_with_confidence[:, :-1], axis=-1)
    confidence = prediction_with_confidence[:, -1]  # Confidence score is the last element
    true_label = int(y_test_loo)
    accuracy = accuracy_score([true_label], [predicted_class])

    predictions.append(predicted_class)
    confidences.append(confidence)
    true_labels.append(true_label)
    accuracies.append(accuracy)

    print(f"Iteration {len(predictions)}: Predicted Class {predicted_class}, True Class {true_label}, Accuracy {accuracy:.4f}, Confidence {confidence[0]:.4f}")
# Out:
# 1/1 [==============================] - 1s 517ms/step
# Iteration 1: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.7438
# 1/1 [==============================] - 0s 123ms/step
# Iteration 2: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5273
# 1/1 [==============================] - 0s 66ms/step
# Iteration 3: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.4020
# 1/1 [==============================] - 0s 93ms/step
# Iteration 4: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 0.4654
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7c800cd10790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 155ms/step
# Iteration 5: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8513
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7c800cd12320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 363ms/step
# Iteration 6: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.7564
# 1/1 [==============================] - 0s 69ms/step
# Iteration 7: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9652
# 1/1 [==============================] - 0s 67ms/step
# Iteration 8: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.4346
# 1/1 [==============================] - 0s 64ms/step
# Iteration 9: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6738
# 1/1 [==============================] - 0s 66ms/step
# Iteration 10: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7175
# 1/1 [==============================] - 0s 73ms/step
# Iteration 11: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.4050
# 1/1 [==============================] - 0s 65ms/step
# Iteration 12: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8963
# 1/1 [==============================] - 0s 66ms/step
# Iteration 13: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.4999
# 1/1 [==============================] - 0s 71ms/step
# Iteration 14: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7955
# 1/1 [==============================] - 0s 66ms/step
# Iteration 15: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5555
# 1/1 [==============================] - 0s 64ms/step
# Iteration 16: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 1.0000
# 1/1 [==============================] - 0s 64ms/step
# Iteration 17: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9973
# 1/1 [==============================] - 0s 94ms/step
# Iteration 18: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8023
# 1/1 [==============================] - 0s 103ms/step
# Iteration 19: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8785
# 1/1 [==============================] - 0s 189ms/step
# Iteration 20: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.8940
# 1/1 [==============================] - 0s 128ms/step
# Iteration 21: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.4609
# 1/1 [==============================] - 0s 266ms/step
# Iteration 22: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.8532
# 1/1 [==============================] - 0s 64ms/step
# Iteration 23: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7647
# 1/1 [==============================] - 0s 64ms/step
# Iteration 24: Predicted Class [2], True Class 0, Accuracy 0.0000, Confidence 0.4854
# 1/1 [==============================] - 0s 73ms/step
# Iteration 25: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7437
# 1/1 [==============================] - 0s 76ms/step
# Iteration 26: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6562
# 1/1 [==============================] - 0s 95ms/step
# Iteration 27: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6183
# 1/1 [==============================] - 0s 96ms/step
# Iteration 28: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8907
# 1/1 [==============================] - 0s 67ms/step
# Iteration 29: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.6992
# 1/1 [==============================] - 0s 68ms/step
# Iteration 30: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6999
# 1/1 [==============================] - 0s 125ms/step
# Iteration 31: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.4440
# 1/1 [==============================] - 0s 227ms/step
# Iteration 32: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5187
# 1/1 [==============================] - 0s 113ms/step
# Iteration 33: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.8099
# 1/1 [==============================] - 0s 108ms/step
# Iteration 34: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5191
# 1/1 [==============================] - 0s 80ms/step
# Iteration 35: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9275
# 1/1 [==============================] - 0s 74ms/step
# Iteration 36: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6872
# 1/1 [==============================] - 0s 74ms/step
# Iteration 37: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.5956
# 1/1 [==============================] - 0s 64ms/step
# Iteration 38: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 0.5542
# 1/1 [==============================] - 0s 250ms/step
# Iteration 39: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7259
# 1/1 [==============================] - 0s 339ms/step
# Iteration 40: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 0.4875
# 1/1 [==============================] - 0s 443ms/step
# Iteration 41: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6570
# 1/1 [==============================] - 0s 66ms/step
# Iteration 42: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9925
# 1/1 [==============================] - 0s 70ms/step
# Iteration 43: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8930
# 1/1 [==============================] - 0s 66ms/step
# Iteration 44: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.7812
# 1/1 [==============================] - 0s 65ms/step
# Iteration 45: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5497
# 1/1 [==============================] - 0s 69ms/step
# Iteration 46: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8754
# 1/1 [==============================] - 0s 300ms/step
# Iteration 47: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5204
# 1/1 [==============================] - 0s 101ms/step
# Iteration 48: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.7120
# 1/1 [==============================] - 0s 190ms/step
# Iteration 49: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7732
# 1/1 [==============================] - 0s 194ms/step
# Iteration 50: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9961
# 1/1 [==============================] - 0s 68ms/step
# Iteration 51: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9555
# 1/1 [==============================] - 0s 65ms/step
# Iteration 52: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.5567
# 1/1 [==============================] - 0s 66ms/step
# Iteration 53: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.6962
# 1/1 [==============================] - 0s 66ms/step
# Iteration 54: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8172
# 1/1 [==============================] - 0s 70ms/step
# Iteration 55: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6934
# 1/1 [==============================] - 0s 107ms/step
# Iteration 56: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6207
# 1/1 [==============================] - 0s 67ms/step
# Iteration 57: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7403
# 1/1 [==============================] - 0s 65ms/step
# Iteration 58: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.5796
# 1/1 [==============================] - 0s 73ms/step
# Iteration 59: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.7281
# 1/1 [==============================] - 0s 218ms/step
# Iteration 60: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9403
# 1/1 [==============================] - 0s 218ms/step
# Iteration 61: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6105
# 1/1 [==============================] - 0s 70ms/step
# Iteration 62: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7207
# 1/1 [==============================] - 0s 70ms/step
# Iteration 63: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5593
# 1/1 [==============================] - 0s 69ms/step
# Iteration 64: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6317
# 1/1 [==============================] - 0s 68ms/step
# Iteration 65: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.8993
# 1/1 [==============================] - 0s 69ms/step
# Iteration 66: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7075
# 1/1 [==============================] - 0s 67ms/step
# Iteration 67: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8079
# 1/1 [==============================] - 0s 69ms/step
# Iteration 68: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5482
# 1/1 [==============================] - 0s 68ms/step
# Iteration 69: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8879
# 1/1 [==============================] - 0s 65ms/step
# Iteration 70: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6334
# 1/1 [==============================] - 0s 107ms/step
# Iteration 71: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6871
# 1/1 [==============================] - 0s 72ms/step
# Iteration 72: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9978
# 1/1 [==============================] - 0s 74ms/step
# Iteration 73: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.4753
# 1/1 [==============================] - 0s 71ms/step
# Iteration 74: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9682
# 1/1 [==============================] - 0s 65ms/step
# Iteration 75: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5295
# 1/1 [==============================] - 0s 126ms/step
# Iteration 76: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5966
# 1/1 [==============================] - 0s 72ms/step
# Iteration 77: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7902
# 1/1 [==============================] - 0s 66ms/step
# Iteration 78: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7003
# 1/1 [==============================] - 0s 78ms/step
# Iteration 79: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7260
# 1/1 [==============================] - 0s 69ms/step
# Iteration 80: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7317
# 1/1 [==============================] - 0s 69ms/step
# Iteration 81: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9293
# 1/1 [==============================] - 0s 71ms/step
# Iteration 82: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9715
# 1/1 [==============================] - 0s 72ms/step
# Iteration 83: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.5667
# 1/1 [==============================] - 0s 71ms/step
# Iteration 84: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.8319
# 1/1 [==============================] - 0s 78ms/step
# Iteration 85: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8487
# 1/1 [==============================] - 0s 100ms/step
# Iteration 86: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.7677
# 1/1 [==============================] - 0s 66ms/step
# Iteration 87: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.5834
# 1/1 [==============================] - 0s 68ms/step
# Iteration 88: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6829
# 1/1 [==============================] - 0s 68ms/step
# Iteration 89: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.7027
# 1/1 [==============================] - 0s 67ms/step
# Iteration 90: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6130
# 1/1 [==============================] - 0s 103ms/step
# Iteration 91: Predicted Class [2], True Class 0, Accuracy 0.0000, Confidence 0.9561
# 1/1 [==============================] - 0s 112ms/step
# Iteration 92: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9652
# 1/1 [==============================] - 0s 68ms/step
# Iteration 93: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8897
# 1/1 [==============================] - 0s 67ms/step
# Iteration 94: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9094
# 1/1 [==============================] - 0s 78ms/step
# Iteration 95: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.8131
# 1/1 [==============================] - 0s 74ms/step
# Iteration 96: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5829
# 1/1 [==============================] - 0s 101ms/step
# Iteration 97: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8275
# 1/1 [==============================] - 0s 73ms/step
# Iteration 98: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.6388
# 1/1 [==============================] - 0s 71ms/step
# Iteration 99: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.8171
# 1/1 [==============================] - 0s 68ms/step
# Iteration 100: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5774
# 1/1 [==============================] - 0s 74ms/step
# Iteration 101: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9022
# 1/1 [==============================] - 0s 112ms/step
# Iteration 102: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6177
# 1/1 [==============================] - 0s 74ms/step
# Iteration 103: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8795
# 1/1 [==============================] - 0s 74ms/step
# Iteration 104: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.9218
# 1/1 [==============================] - 0s 68ms/step
# Iteration 105: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8547
# 1/1 [==============================] - 0s 67ms/step
# Iteration 106: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.7489
# 1/1 [==============================] - 0s 100ms/step
# Iteration 107: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5804
# 1/1 [==============================] - 0s 71ms/step
# Iteration 108: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7760
# 1/1 [==============================] - 0s 65ms/step
# Iteration 109: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.8846
# 1/1 [==============================] - 0s 374ms/step
# Iteration 110: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9294
# 1/1 [==============================] - 0s 69ms/step
# Iteration 111: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7625
# 1/1 [==============================] - 0s 67ms/step
# Iteration 112: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9072
# 1/1 [==============================] - 0s 70ms/step
# Iteration 113: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5216
# 1/1 [==============================] - 0s 69ms/step
# Iteration 114: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6922
# 1/1 [==============================] - 0s 124ms/step
# Iteration 115: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7809
# 1/1 [==============================] - 0s 74ms/step
# Iteration 116: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7346
# 1/1 [==============================] - 0s 72ms/step
# Iteration 117: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.7098
# 1/1 [==============================] - 0s 106ms/step
# Iteration 118: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9996
# 1/1 [==============================] - 0s 92ms/step
# Iteration 119: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5193
# 1/1 [==============================] - 0s 68ms/step
# Iteration 120: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6915
# 1/1 [==============================] - 0s 76ms/step
# Iteration 121: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8045
# 1/1 [==============================] - 0s 74ms/step
# Iteration 122: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7848
# 1/1 [==============================] - 0s 66ms/step
# Iteration 123: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9309
# 1/1 [==============================] - 0s 68ms/step
# Iteration 124: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6542
# 1/1 [==============================] - 0s 73ms/step
# Iteration 125: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5017
# 1/1 [==============================] - 0s 71ms/step
# Iteration 126: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.4961
# 1/1 [==============================] - 0s 76ms/step
# Iteration 127: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.6494
# 1/1 [==============================] - 0s 71ms/step
# Iteration 128: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.7780
# 1/1 [==============================] - 0s 98ms/step
# Iteration 129: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8321
# 1/1 [==============================] - 0s 87ms/step
# Iteration 130: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8853
# 1/1 [==============================] - 0s 85ms/step
# Iteration 131: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9881
# 1/1 [==============================] - 0s 68ms/step
# Iteration 132: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8729
# 1/1 [==============================] - 0s 72ms/step
# Iteration 133: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6772
# 1/1 [==============================] - 0s 122ms/step
# Iteration 134: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8140
# 1/1 [==============================] - 0s 141ms/step
# Iteration 135: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9571
# 1/1 [==============================] - 0s 72ms/step
# Iteration 136: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.9020
# 1/1 [==============================] - 0s 70ms/step
# Iteration 137: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9216
# 1/1 [==============================] - 0s 72ms/step
# Iteration 138: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9669
# 1/1 [==============================] - 0s 68ms/step
# Iteration 139: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9615
# 1/1 [==============================] - 0s 117ms/step
# Iteration 140: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9660
# 1/1 [==============================] - 0s 68ms/step
# Iteration 141: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7970
# 1/1 [==============================] - 0s 85ms/step
# Iteration 142: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.4787
# 1/1 [==============================] - 0s 73ms/step
# Iteration 143: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6131
# 1/1 [==============================] - 0s 67ms/step
# Iteration 144: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6726
# 1/1 [==============================] - 0s 95ms/step
# Iteration 145: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8178
# 1/1 [==============================] - 0s 74ms/step
# Iteration 146: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9598
# 1/1 [==============================] - 0s 69ms/step
# Iteration 147: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9996
# 1/1 [==============================] - 0s 65ms/step
# Iteration 148: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8375
# 1/1 [==============================] - 0s 67ms/step
# Iteration 149: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.6121
# 1/1 [==============================] - 0s 68ms/step
# Iteration 150: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9505
# 1/1 [==============================] - 0s 117ms/step
# Iteration 151: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9985
# 1/1 [==============================] - 0s 71ms/step
# Iteration 152: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9582
# 1/1 [==============================] - 0s 65ms/step
# Iteration 153: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7416
# 1/1 [==============================] - 0s 96ms/step
# Iteration 154: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5642
# 1/1 [==============================] - 0s 116ms/step
# Iteration 155: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5589
# 1/1 [==============================] - 0s 77ms/step
# Iteration 156: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9047
# 1/1 [==============================] - 0s 86ms/step
# Iteration 157: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.5928
# 1/1 [==============================] - 0s 70ms/step
# Iteration 158: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9009
# 1/1 [==============================] - 0s 71ms/step
# Iteration 159: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.7648
# 1/1 [==============================] - 0s 89ms/step
# Iteration 160: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9957
# 1/1 [==============================] - 0s 99ms/step
# Iteration 161: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8014
# 1/1 [==============================] - 0s 69ms/step
# Iteration 162: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9767
# 1/1 [==============================] - 0s 68ms/step
# Iteration 163: Predicted Class [1], True Class 2, Accuracy 0.0000, Confidence 0.4707
# 1/1 [==============================] - 0s 68ms/step
# Iteration 164: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7268
# 1/1 [==============================] - 0s 73ms/step
# Iteration 165: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.8032
# 1/1 [==============================] - 0s 97ms/step
# Iteration 166: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8521
# 1/1 [==============================] - 0s 70ms/step
# Iteration 167: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5424
# 1/1 [==============================] - 0s 98ms/step
# Iteration 168: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6039
# 1/1 [==============================] - 0s 70ms/step
# Iteration 169: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5814
# 1/1 [==============================] - 0s 66ms/step
# Iteration 170: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9680
# 1/1 [==============================] - 0s 71ms/step
# Iteration 171: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9967
# 1/1 [==============================] - 0s 66ms/step
# Iteration 172: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9720
# 1/1 [==============================] - 0s 64ms/step
# Iteration 173: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6909
# 1/1 [==============================] - 0s 70ms/step
# Iteration 174: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.9670
# 1/1 [==============================] - 0s 64ms/step
# Iteration 175: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9374
# 1/1 [==============================] - 0s 65ms/step
# Iteration 176: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.7341
# 1/1 [==============================] - 0s 77ms/step
# Iteration 177: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9089
# 1/1 [==============================] - 0s 69ms/step
# Iteration 178: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9056
# 1/1 [==============================] - 0s 72ms/step
# Iteration 179: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9115
# 1/1 [==============================] - 0s 68ms/step
# Iteration 180: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.6388
# 1/1 [==============================] - 0s 93ms/step
# Iteration 181: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.4974
# 1/1 [==============================] - 0s 74ms/step
# Iteration 182: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8572
# 1/1 [==============================] - 0s 65ms/step
# Iteration 183: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 1.0000
# 1/1 [==============================] - 0s 69ms/step
# Iteration 184: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6824
# 1/1 [==============================] - 0s 70ms/step
# Iteration 185: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6752
# 1/1 [==============================] - 0s 70ms/step
# Iteration 186: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.8034
# 1/1 [==============================] - 0s 68ms/step
# Iteration 187: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7646
# 1/1 [==============================] - 0s 77ms/step
# Iteration 188: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9035
# 1/1 [==============================] - 0s 69ms/step
# Iteration 189: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.7833
# 1/1 [==============================] - 0s 116ms/step
# Iteration 190: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 0.8257
# 1/1 [==============================] - 0s 137ms/step
# Iteration 191: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9344
# 1/1 [==============================] - 0s 70ms/step
# Iteration 192: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.8144
# 1/1 [==============================] - 0s 65ms/step
# Iteration 193: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8333
# 1/1 [==============================] - 0s 71ms/step
# Iteration 194: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.8561
# 1/1 [==============================] - 0s 69ms/step
# Iteration 195: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7940
# 1/1 [==============================] - 0s 96ms/step
# Iteration 196: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.9618
# 1/1 [==============================] - 0s 109ms/step
# Iteration 197: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5575
# 1/1 [==============================] - 0s 69ms/step
# Iteration 198: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9306
# 1/1 [==============================] - 0s 67ms/step
# Iteration 199: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.6337
# 1/1 [==============================] - 0s 66ms/step
# Iteration 200: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 0.9115
# 1/1 [==============================] - 0s 69ms/step
# Iteration 201: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9254
# 1/1 [==============================] - 0s 112ms/step
# Iteration 202: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6527
# 1/1 [==============================] - 0s 68ms/step
# Iteration 203: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.8706
# 1/1 [==============================] - 0s 68ms/step
# Iteration 204: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9943
# 1/1 [==============================] - 0s 66ms/step
# Iteration 205: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.8546
# 1/1 [==============================] - 0s 63ms/step
# Iteration 206: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9158
# 1/1 [==============================] - 0s 108ms/step
# Iteration 207: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7371
# 1/1 [==============================] - 0s 67ms/step
# Iteration 208: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9999
# 1/1 [==============================] - 0s 65ms/step
# Iteration 209: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.8484
# 1/1 [==============================] - 0s 84ms/step
# Iteration 210: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.7643
# 1/1 [==============================] - 0s 70ms/step
# Iteration 211: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9858
# 1/1 [==============================] - 0s 100ms/step
# Iteration 212: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6625
# 1/1 [==============================] - 0s 66ms/step
# Iteration 213: Predicted Class [2], True Class 2, Accuracy 1.0000, Confidence 0.9954
# 1/1 [==============================] - 0s 64ms/step
# Iteration 214: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.7495
# 1/1 [==============================] - 0s 64ms/step
# Iteration 215: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9850
# 1/1 [==============================] - 0s 69ms/step
# Iteration 216: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7577
# 1/1 [==============================] - 0s 70ms/step
# Iteration 217: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5793
# 1/1 [==============================] - 0s 82ms/step
# Iteration 218: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9848
# 1/1 [==============================] - 0s 67ms/step
# Iteration 219: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8977
# 1/1 [==============================] - 0s 71ms/step
# Iteration 220: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9305
# 1/1 [==============================] - 0s 65ms/step
# Iteration 221: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5602
# 1/1 [==============================] - 0s 71ms/step
# Iteration 222: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7346
# 1/1 [==============================] - 0s 70ms/step
# Iteration 223: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9789
# 1/1 [==============================] - 0s 77ms/step
# Iteration 224: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.4907
# 1/1 [==============================] - 0s 71ms/step
# Iteration 225: Predicted Class [0], True Class 1, Accuracy 0.0000, Confidence 0.5087
# 1/1 [==============================] - 0s 83ms/step
# Iteration 226: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5669
# 1/1 [==============================] - 0s 122ms/step
# Iteration 227: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8884
# 1/1 [==============================] - 0s 119ms/step
# Iteration 228: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9920
# 1/1 [==============================] - 0s 71ms/step
# Iteration 229: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8835
# 1/1 [==============================] - 0s 90ms/step
# Iteration 230: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9139
# 1/1 [==============================] - 0s 72ms/step
# Iteration 231: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6868
# 1/1 [==============================] - 0s 69ms/step
# Iteration 232: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.6004
# 1/1 [==============================] - 0s 69ms/step
# Iteration 233: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9262
# 1/1 [==============================] - 0s 69ms/step
# Iteration 234: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8821
# 1/1 [==============================] - 0s 74ms/step
# Iteration 235: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8949
# 1/1 [==============================] - 0s 69ms/step
# Iteration 236: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9377
# 1/1 [==============================] - 0s 113ms/step
# Iteration 237: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7695
# 1/1 [==============================] - 0s 65ms/step
# Iteration 238: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9389
# 1/1 [==============================] - 0s 70ms/step
# Iteration 239: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.6517
# 1/1 [==============================] - 0s 66ms/step
# Iteration 240: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9655
# 1/1 [==============================] - 0s 79ms/step
# Iteration 241: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.5117
# 1/1 [==============================] - 0s 106ms/step
# Iteration 242: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.5101
# 1/1 [==============================] - 0s 70ms/step
# Iteration 243: Predicted Class [2], True Class 0, Accuracy 0.0000, Confidence 1.0000
# 1/1 [==============================] - 0s 72ms/step
# Iteration 244: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.5498
# 1/1 [==============================] - 0s 66ms/step
# Iteration 245: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9636
# 1/1 [==============================] - 0s 75ms/step
# Iteration 246: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.4877
# 1/1 [==============================] - 0s 96ms/step
# Iteration 247: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8903
# 1/1 [==============================] - 0s 70ms/step
# Iteration 248: Predicted Class [2], True Class 1, Accuracy 0.0000, Confidence 0.5187
# 1/1 [==============================] - 0s 74ms/step
# Iteration 249: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6903
# 1/1 [==============================] - 0s 67ms/step
# Iteration 250: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8491
# 1/1 [==============================] - 0s 86ms/step
# Iteration 251: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7983
# 1/1 [==============================] - 0s 73ms/step
# Iteration 252: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8110
# 1/1 [==============================] - 0s 109ms/step
# Iteration 253: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9719
# 1/1 [==============================] - 0s 75ms/step
# Iteration 254: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.7927
# 1/1 [==============================] - 0s 68ms/step
# Iteration 255: Predicted Class [1], True Class 0, Accuracy 0.0000, Confidence 0.4558
# 1/1 [==============================] - 0s 66ms/step
# Iteration 256: Predicted Class [1], True Class 1, Accuracy 1.0000, Confidence 0.9351
# 1/1 [==============================] - 0s 65ms/step
# Iteration 257: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9071
# 1/1 [==============================] - 0s 106ms/step
# Iteration 258: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.6447
# 1/1 [==============================] - 0s 66ms/step
# Iteration 259: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.8583
# 1/1 [==============================] - 0s 65ms/step
# Iteration 260: Predicted Class [0], True Class 0, Accuracy 1.0000, Confidence 0.9814

# %%
# Calculate Confidence for Each Class
confidence_values = np.zeros((3, 3))
for true_label, confidence in zip(true_labels, confidences):
    confidence_values[true_label] += confidence

# Overall Average Confidence Score
avg_confidence_overall = np.mean(confidences)
print(f"\nOverall Average Confidence Score: {avg_confidence_overall:.4f}")

# Normalize Confidence Values
row_sums = confidence_values.sum(axis=1)
confidence_values_normalized = confidence_values / row_sums[:, np.newaxis]

# Calculate TP, FP, TN, FN
conf_matrix = confusion_matrix(true_labels, predictions)
TP = np.diag(conf_matrix)
FP = np.sum(conf_matrix, axis=0) - TP
FN = np.sum(conf_matrix, axis=1) - TP
TN = np.sum(conf_matrix) - (TP + FP + FN)

# Print TP, FP, TN, FN
print("\nTrue Positives (TP):", TP)
print("False Positives (FP):", FP)
print("True Negatives (TN):", TN)
print("False Negatives (FN):", FN)

# Print Confusion Matrix
print("\nConfusion Matrix:")
print(conf_matrix)

# Calculate average accuracy and standard deviation
avg_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Standard Deviation of Accuracy: {std_accuracy:.4f}")

# Average Confidence of TP, FP, TN, FN
avg_confidence_TP = np.mean([conf for i, conf in enumerate(confidences) if i in TP])
avg_confidence_FP = np.mean([conf for i, conf in enumerate(confidences) if i in FP])
avg_confidence_TN = np.mean([conf for i, conf in enumerate(confidences) if i in TN])
avg_confidence_FN = np.mean([conf for i, conf in enumerate(confidences) if i in FN])

print("\nAverage Confidence of True Positives (TP):", avg_confidence_TP)
print("Average Confidence of False Positives (FP):", avg_confidence_FP)
print("Average Confidence of True Negatives (TN):", avg_confidence_TN)
print("Average Confidence of False Negatives (FN):", avg_confidence_FN)

# Standard deviation of confidence scores
std_confidence = np.std(confidences)
print(f"\nStandard Deviation of Confidence Scores: {std_confidence:.4f}")

# Calculate F1 Score
f1 = f1_score(true_labels, predictions, average='macro')
print(f"\nF1 Score: {f1:.4f}")

# Calculate Precision
precision = precision_score(true_labels, predictions, average='macro')
print(f"Precision: {precision:.4f}")

# Calculate Recall
recall = recall_score(true_labels, predictions, average='macro')
print(f"Recall: {recall:.4f}")
# Out:
# Overall Average Confidence Score: 0.7888
#
# True Positives (TP): [290 277 339]
# False Positives (FP): [54 89 40]
# True Negatives (TN): [672 637 686]
# False Negatives (FN): [73 86 24]
#
# Confusion Matrix:
# [[290  67   6]
#  [ 52 277  34]
#  [  2  22 339]]
# Average Accuracy: 0.8320
# Standard Deviation of Accuracy: 0.3739
#
# Average Confidence of True Positives (TP): 0.94011134
# Average Confidence of False Positives (FP): 0.66895586
# Average Confidence of True Negatives (TN): 0.5368771
# Average Confidence of False Negatives (FN): 0.77827674
#
# Standard Deviation of Confidence Scores: 0.1678
#
# F1 Score: 0.8314
# Precision: 0.8314
# Recall: 0.8320
